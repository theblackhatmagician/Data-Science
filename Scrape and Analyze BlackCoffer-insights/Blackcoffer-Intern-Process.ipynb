# %% [markdown]
# ### Analyzing the Text Files

# %%
#Reading the Output Excel File

# %%
import pandas as pd

# %%
output = pd.read_excel(r"./Output Data Structure.xlsx")

# %%
for i in output:
    print(i)
# Out:
# URL_ID
# URL
# POSITIVE SCORE
# NEGATIVE SCORE
# POLARITY SCORE
# SUBJECTIVITY SCORE
# AVG SENTENCE LENGTH
# PERCENTAGE OF COMPLEX WORDS
# FOG INDEX
# AVG NUMBER OF WORDS PER SENTENCE
# COMPLEX WORD COUNT
# WORD COUNT
# SYLLABLE PER WORD
# PERSONAL PRONOUNS
# AVG WORD LENGTH

# %%
#Read all the TEXT Files in pandas

# %%
data = pd.DataFrame(columns=['URL_NO','Document'])
for i in output['URL_ID']:
    f = open('./scrap_files/'+str(i), 'rb')
    rs = {'Document':f.read().decode('utf-8'),'URL_NO':i}
    data = data.append(rs, ignore_index = True)

# %%
data.head()
# Out:
#    URL_NO                                           Document
# 0     1.0  Is telehealth the future of healthcare?\nCovid...
# 1     2.0  How Telehealth and Telemedicine helping people...
# 2     3.0  Is telemedicine effective in treating patients...
# 3     4.0  The Future of Telehealth Services\nTelemedicin...
# 4     5.0  How are people diverted to Telehealth services...

# %%
#Tokenize all the documents

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = []
for i in data['Document']:
    tokens.append(word_tokenize(i))
data['token'] = tokens

# %%
data.head()
# Out:
#    URL_NO                                           Document  \
# 0     1.0  Is telehealth the future of healthcare?\nCovid...
# 1     2.0  How Telehealth and Telemedicine helping people...
# 2     3.0  Is telemedicine effective in treating patients...
# 3     4.0  The Future of Telehealth Services\nTelemedicin...
# 4     5.0  How are people diverted to Telehealth services...
#
#                                                token
# 0  [Is, telehealth, the, future, of, healthcare, ...
# 1  [How, Telehealth, and, Telemedicine, helping, ...
# 2  [Is, telemedicine, effective, in, treating, pa...
# 3  [The, Future, of, Telehealth, Services, Teleme...
# 4  [How, are, people, diverted, to, Telehealth, s...

# %%
#Read Stopwords

# %%
f = open('./StopWords/StopWords_Auditor.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
stop_auditor = read.split("\r\n")

# %%
print(stop_auditor)
# Out:
# ['ernst', 'young', 'deloitte', 'touche', 'kpmg', 'pricewaterhousecoopers', 'pricewaterhouse', 'coopers']

# %%
f = open('./StopWords/StopWords_Currencies.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
read= read.split("\r\n")

# %%
stop_currency = []
for i in read:
    stop_currency.append(i.split("|")[0].strip())

# %%
print(stop_currency)
# Out:
# ['afghani', 'ariary', 'baht', 'balboa', 'birr', 'bolivar', 'boliviano', 'cedi', 'colon', 'córdoba', 'dalasi', 'denar', 'dinar', 'dirham', 'dobra', 'dong', 'dram', 'escudo', 'euro', 'florin', 'forint', 'gourde', 'guarani', 'gulden', 'hryvnia', 'kina', 'kip', 'konvertibilna marka', 'koruna', 'krona', 'krone', 'kroon', 'kuna', 'kwacha', 'kwanza', 'kyat', 'lari', 'lats', 'lek', 'lempira', 'leone', 'leu', 'lev', 'lilangeni', 'lira', 'litas', 'loti', 'manat', 'metical', 'naira', 'nakfa', 'new lira', 'new sheqel', 'ngultrum', 'nuevo sol', 'ouguiya', 'pataca', 'peso', 'pound', 'pula', 'quetzal', 'rand', 'real', 'renminbi', 'rial', 'riel', 'ringgit', 'riyal', 'ruble', 'rufiyaa', 'rupee', 'rupee', 'rupiah', 'shilling', 'som', 'somoni', 'special drawing rights', 'taka', 'tala', 'tenge', 'tugrik', 'vatu', 'won', 'yen', 'zloty']

# %%
f = open('./StopWords/StopWords_DatesandNumbers.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
read= read.split("\r\n")

# %%
stop_datesNnumb = []
for i in read:
    stop_datesNnumb.append(i.split("|")[0].strip())

# %%
print(stop_datesNnumb)
# Out:
# ['hundred', 'thousand', 'million', 'billion', 'trillion', 'date', 'annual', 'annually', 'annum', 'year', 'yearly', 'quarter', 'quarterly', 'qtr', 'month', 'monthly', 'week', 'weekly', 'day', 'daily', 'january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december', 'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'sept', 'oct', 'nov', 'dec', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen', 'nineteen', 'twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety', 'first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth', 'tenth', 'i', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'x', 'xi', 'xii', 'xiii', 'xiv', 'xv', 'xvi', 'xvii', 'xviii', 'xix', 'xx']

# %%
f = open('./StopWords/StopWords_Generic.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
stop_generic = read.split("\r\n")

# %%
print(stop_generic)
# Out:
# ['about', 'above', 'after', 'again', 'all', 'am', 'among', 'an', 'and', 'any', 'are', 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'did', 'do', 'does', 'doing', 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'has', 'have', 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'if', 'in', 'into', 'is', 'it', 'its', 'itself', 'just', 'me', 'more', 'most', 'my', 'myself', 'no', 'nor', 'not', 'now', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'same', 'she', 'should', 'so', 'some', 'such', 'than', 'that', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 'very', 'was', 'we', 'were', 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'with', 'you', 'your', 'yours', 'yourself', 'yourselves']

# %%
f = open('./StopWords/StopWords_GenericLong.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
stop_genericLong = read.split("\r\n")

# %%
print(stop_genericLong)
# Out:
# ['a', "a's", 'able', 'about', 'above', 'according', 'accordingly', 'across', 'actually', 'after', 'afterwards', 'again', 'against', "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear', 'appreciate', 'appropriate', 'are', "aren't", 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away', 'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'best', 'better', 'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon", "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause', 'causes', 'certain', 'certainly', 'changes', 'clearly', 'co', 'com', 'come', 'comes', 'concerning', 'consequently', 'consider', 'considering', 'contain', 'containing', 'con
# ...

# %%
f = open('./StopWords/StopWords_Geographic.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
read = read.split("\r\n")

# %%
stop_geographic = []
for i in read:
    stop_geographic .append(i.split("|")[0].strip())

# %%
print(stop_geographic)
# Out:
# ['united', 'state', 'north', 'south', 'east', 'northeast', 'northwest', 'southeast', 'southwest', 'west', 'ocean', 'sea', 'lake', 'river', 'creek', 'gulf', 'mountain', 'street', 'boulevard', 'blvd', 'parkway', 'city', 'county', 'country', 'pacific', 'atlantic', 'indian', 'mediterranean', 'commonwealth', 'america', 'american', 'york', 'chicago', 'las', 'vegas', 'los', 'angeles', 'milwaukee', 'sunnyvale', 'fremont', 'cincinnati', 'philadelphia', 'miami', 'dallas', 'fort', 'boston', 'houston', 'washington', 'atlanta', 'detroit', 'san', 'fransico', 'phoenix', 'seattle', 'diego', 'minneapolis', 'memphis', 'denver', 'st', 'louis', 'pittsburgh', 'manhattan', 'hollywood', 'columbus', 'indianapolis', 'mumbai', 'karachi', 'ontario', 'toronto', 'cambridge', 'delhi', 'sao', 'paulo', 'shanghai', 'moscow', 'seoul', 'istanbul', 'tokyo', 'jakarta', 'beijing', 'london', 'luxembourg', 'singapore', 'republic', 'china', 'india', 'indonesia', 'brazil', 'brazilian', 'pakistan', 'bangladesh', 'russia', 'ni
# ...

# %%
f = open('./StopWords/StopWords_Names.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
read = read.split("\r\n")

# %%
stop_names = []
for i in read:
    stop_names.append(i.split("|")[0].strip())

# %%
print(stop_names)
# Out:
# ['smith', 'johnson', 'williams', 'jones', 'brown', 'davis', 'miller', 'wilson', 'moore', 'taylor', 'anderson', 'thomas', 'jackson', 'white', 'harris', 'martin', 'thompson', 'garcia', 'martinez', 'robinson', 'clark', 'rodriguez', 'lewis', 'lee', 'walker', 'hall', 'allen', 'young', 'hernandez', 'king', 'wright', 'lopez', 'hill', 'scott', 'green', 'adams', 'baker', 'gonzalez', 'nelson', 'carter', 'mitchell', 'perez', 'roberts', 'turner', 'phillips', 'campbell', 'parker', 'evans', 'edwards', 'collins', 'stewart', 'sanchez', 'morris', 'rogers', 'reed', 'cook', 'morgan', 'bell', 'murphy', 'bailey', 'rivera', 'cooper', 'richardson', 'cox', 'howard', 'ward', 'torres', 'peterson', 'gray', 'ramirez', 'james', 'watson', 'brooks', 'kelly', 'sanders', 'price', 'bennett', 'wood', 'barnes', 'ross', 'henderson', 'coleman', 'jenkins', 'perry', 'powell', 'long', 'patterson', 'hughes', 'flores', 'washington', 'butler', 'simmons', 'foster', 'gonzales', 'bryant', 'alexander', 'russell', 'griffin', 'diaz'
# ...

# %%
total_stop = stop_auditor + stop_currency + stop_datesNnumb + stop_generic + stop_genericLong + stop_geographic + stop_names

# %%
print(total_stop)
# Out:
# ['ernst', 'young', 'deloitte', 'touche', 'kpmg', 'pricewaterhousecoopers', 'pricewaterhouse', 'coopers', 'afghani', 'ariary', 'baht', 'balboa', 'birr', 'bolivar', 'boliviano', 'cedi', 'colon', 'córdoba', 'dalasi', 'denar', 'dinar', 'dirham', 'dobra', 'dong', 'dram', 'escudo', 'euro', 'florin', 'forint', 'gourde', 'guarani', 'gulden', 'hryvnia', 'kina', 'kip', 'konvertibilna marka', 'koruna', 'krona', 'krone', 'kroon', 'kuna', 'kwacha', 'kwanza', 'kyat', 'lari', 'lats', 'lek', 'lempira', 'leone', 'leu', 'lev', 'lilangeni', 'lira', 'litas', 'loti', 'manat', 'metical', 'naira', 'nakfa', 'new lira', 'new sheqel', 'ngultrum', 'nuevo sol', 'ouguiya', 'pataca', 'peso', 'pound', 'pula', 'quetzal', 'rand', 'real', 'renminbi', 'rial', 'riel', 'ringgit', 'riyal', 'ruble', 'rufiyaa', 'rupee', 'rupee', 'rupiah', 'shilling', 'som', 'somoni', 'special drawing rights', 'taka', 'tala', 'tenge', 'tugrik', 'vatu', 'won', 'yen', 'zloty', 'hundred', 'thousand', 'million', 'billion', 'trillion', 'date', '
# ...

# %%
#Read Positive and Negative Words

# %%
f = open('./polarity/positive-words.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
positive_w= read.split("\n")

# %%
print(positive_w)
# Out:
# ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accurate', 'accurately', 'achievable', 'achievement', 'achievements', 'achievible', 'acumen', 'adaptable', 'adaptive', 'adequate', 'adjustable', 'admirable', 'admirably', 'admiration', 'admire', 'admirer', 'admiring', 'admiringly', 'adorable', 'adore', 'adored', 'adorer', 'adoring', 'adoringly', 'adroit', 'adroitly', 'adulate', 'adulation', 'adulatory', 'advanced', 'advantage', 'advantageous', 'advantageously', 'advantages', 'adventuresome', 'adventurous', 'advocate', 'advocated', 'advocates', 'affability', 'affable', 'affably', 'affectation', 'affection', 'affectionate', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affluence', 'affluent', 'afford', 'affordable', 'affordably', 'afordable', 'agile', 'agilely', 'agility', 'agreeable', '
# ...

# %%
f = open('./polarity/negative-words.txt', 'rb')
read = f.read().decode('ISO-8859-1').strip().lower()
negative_w= read.split("\n")

# %%
print(negative_w)
# Out:
# ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted', 'aborts', 'abrade', 'abrasive', 'abrupt', 'abruptly', 'abscond', 'absence', 'absent-minded', 'absentee', 'absurd', 'absurdity', 'absurdly', 'absurdness', 'abuse', 'abused', 'abuses', 'abusive', 'abysmal', 'abysmally', 'abyss', 'accidental', 'accost', 'accursed', 'accusation', 'accusations', 'accuse', 'accuses', 'accusing', 'accusingly', 'acerbate', 'acerbic', 'acerbically', 'ache', 'ached', 'aches', 'achey', 'aching', 'acrid', 'acridly', 'acridness', 'acrimonious', 'acrimoniously', 'acrimony', 'adamant', 'adamantly', 'addict', 'addicted', 'addicting', 'addicts', 'admonish', 'admonisher', 'admonishingly', 'admonishment', 'admonition', 'adulterate', 'adulterated', 'adulteration', 'adulterier', 'adversarial', 'adversary', 'adverse', 'adversity', 'afflict', 'affliction', 'afflictive', 'affront', 'afraid', 'aggravate', 'aggravating', 'aggravation', 'aggression', 'aggre
# ...

# %% [markdown]
# We Have : positive_w, negative_w, total_stop, data

# %%
#Remove Stop Words

# %%
filtered_words = []
for i in data['token']:
    filtered_words.append([w.lower() for w in i if not w in total_stop and w.isalpha()])

# %%
data['filtered_token'] = filtered_words

# %%
data.head()
# Out:
#    URL_NO                                           Document  \
# 0     1.0  Is telehealth the future of healthcare?\nCovid...
# 1     2.0  How Telehealth and Telemedicine helping people...
# 2     3.0  Is telemedicine effective in treating patients...
# 3     4.0  The Future of Telehealth Services\nTelemedicin...
# 4     5.0  How are people diverted to Telehealth services...
#
#                                                token  \
# 0  [Is, telehealth, the, future, of, healthcare, ...
# 1  [How, Telehealth, and, Telemedicine, helping, ...
# 2  [Is, telemedicine, effective, in, treating, pa...
# 3  [The, Future, of, Telehealth, Services, Teleme...
# 4  [How, are, people, diverted, to, Telehealth, s...
#
#                                       filtered_token  words_count
# 0  [is, telehealth, future, healthcare, paved, ad...          325
# 1  [how, telehealth, telemedicine, helping, peopl...          413
# 2  [is, telemedicine, effective, treating, patien...          910
# ...

# %% [raw]
# To Find
#
# POSITIVE SCORE
# NEGATIVE SCORE
# POLARITY SCORE
# SUBJECTIVITY SCORE
# AVG SENTENCE LENGTH
# PERCENTAGE OF COMPLEX WORDS
# FOG INDEX
# AVG NUMBER OF WORDS PER SENTENCE
# COMPLEX WORD COUNT
# WORD COUNT
# SYLLABLE PER WORD
# PERSONAL PRONOUNS
# AVG WORD LENGTH

# %%
#Find Polarity, positive, negative and subjectivity

# %%
positive = []
negative = []
polarity = []
subjectivity = []
words_count = []

for filtered_words in data['filtered_token']:
    pos = 0
    neg = 0
    words = 0
    for j in filtered_words:
        words += 1
        if j in positive_w:
            pos += 1
        elif j in negative_w:
            neg += 1
    polar = (pos-neg)/((pos+neg) + 0.000001)
    subject = (pos+neg)/(words + 0.000001)
    
    positive.append(pos)
    negative.append(neg)
    polarity.append(polar)
    subjectivity.append(subject)
    words_count.append(words)

# %%
output['POSITIVE SCORE'] = positive
output['NEGATIVE SCORE'] = negative
output['POLARITY SCORE'] = polar
output['SUBJECTIVITY SCORE'] = subjectivity
output['WORD COUNT'] = words_count
output.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0     1.0  https://insights.blackcoffer.com/is-telehealth...              30
# 1     2.0  https://insights.blackcoffer.com/how-telehealt...              35
# 2     3.0  https://insights.blackcoffer.com/is-telemedici...              71
# 3     4.0  https://insights.blackcoffer.com/is-telehealth...              57
# 4     5.0  https://insights.blackcoffer.com/how-people-di...              71
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0               5       -0.076923            0.107692                  NaN
# 1              16       -0.076923            0.123487                  NaN
# 2              28       -0.076923            0.108791                  NaN
# 3              22       -0.076923            0.083158                  NaN
# 4              33       -0.076923            0.115684                  NaN
#
# ...

# %%
#Count of Complex Words and Count of Syllable

# %%
#pyphen package to find the syllable count
#Syllable count has certain rules than the count of vowels, Hence pyphen package is preferred
from pyphen import Pyphen
p = Pyphen(lang='en_US')

# %%
complex_word = []
syllable_count = []
for doc in data['token']:
    complex_count = 0
    syllable = 0
    for i in doc:
        syllable += len(p.positions(i))+1
        if syllable > 2:
            complex_count+=1
    complex_word.append(complex_count)
    syllable_count.append(syllable)

# %%
output['COMPLEX WORD COUNT'] = complex_word
#Total syllable count in each document is found, as it is not specified and a document has multiple words.
output['SYLLABLE PER WORD'] = syllable_count
output.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0     1.0  https://insights.blackcoffer.com/is-telehealth...              30
# 1     2.0  https://insights.blackcoffer.com/how-telehealt...              35
# 2     3.0  https://insights.blackcoffer.com/is-telemedici...              71
# 3     4.0  https://insights.blackcoffer.com/is-telehealth...              57
# 4     5.0  https://insights.blackcoffer.com/how-people-di...              71
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0               5       -0.076923            0.107692                  NaN
# 1              16       -0.076923            0.123487                  NaN
# 2              28       -0.076923            0.108791                  NaN
# 3              22       -0.076923            0.083158                  NaN
# 4              33       -0.076923            0.115684                  NaN
#
# ...

# %%
#Sentence count and Word count for AVG NUMBER OF WORDS PER SENTENCE, FOG INDEX

# %%
from nltk import sent_tokenize

# %%
sentence_count = []
for i in data['Document']:
    sentences = sent_tokenize(i)
    sentence_count.append(len(sentences))

# %%
word_length = []
char_length = []
for i in tokens:
    word_length.append(len(i))
    ch_count = 0
    for j in i:
        ch_count += len(j)
    char_length.append(ch_count)

# %%
average_length = []
complex_percentage = []
fog_index = []
average_word_length = []
for i in range(150):
    average_length.append(word_length[i]/sentence_count[i])
    complex_percentage.append(complex_word[i]/word_length[i])
    fog_index.append(0.4*((word_length[i]/sentence_count[i])+(complex_word[i]/word_length[i])))
    average_word_length.append(char_length[i]/word_length[i])

# %%
output['AVG NUMBER OF WORDS PER SENTENCE'] = average_length
output['AVG SENTENCE LENGTH'] = average_length
output['PERCENTAGE OF COMPLEX WORDS'] = complex_percentage
output['FOG INDEX'] = fog_index
output['AVG WORD LENGTH'] = average_word_length
output
# Out:
#      URL_ID                                                URL  \
# 0       1.0  https://insights.blackcoffer.com/is-telehealth...
# 1       2.0  https://insights.blackcoffer.com/how-telehealt...
# 2       3.0  https://insights.blackcoffer.com/is-telemedici...
# 3       4.0  https://insights.blackcoffer.com/is-telehealth...
# 4       5.0  https://insights.blackcoffer.com/how-people-di...
# ..      ...                                                ...
# 145   146.0  https://insights.blackcoffer.com/blockchain-fo...
# 146   147.0  https://insights.blackcoffer.com/the-future-of...
# 147   148.0  https://insights.blackcoffer.com/big-data-anal...
# 148   149.0  https://insights.blackcoffer.com/business-anal...
# 149   150.0  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                30               5       -0.076923            0.107692
# ...

# %%
#Personal Pronouns

# %%
pro_count = 0
for i in filtered_words:
    if i in ['i','we','my','ours','us']:
        pro_count += 1
pro_count
# Out:
# 0

# %%
import re

# %%
pronoun_count = []
for i in data['Document']:
    #re.I makes case insensitive, but ?-i makes us case sensitive to avoid US
    pronounRegex = re.compile(r'\b(I|we|my|ours|(?-i:us))\b',re.I)
    pronoun = pronounRegex.findall(i)
    pronoun_count.append(len(pronoun))

# %%
output['PERSONAL PRONOUNS'] = pronoun_count

# %%
output
# Out:
#      URL_ID                                                URL  \
# 0       1.0  https://insights.blackcoffer.com/is-telehealth...
# 1       2.0  https://insights.blackcoffer.com/how-telehealt...
# 2       3.0  https://insights.blackcoffer.com/is-telemedici...
# 3       4.0  https://insights.blackcoffer.com/is-telehealth...
# 4       5.0  https://insights.blackcoffer.com/how-people-di...
# ..      ...                                                ...
# 145   146.0  https://insights.blackcoffer.com/blockchain-fo...
# 146   147.0  https://insights.blackcoffer.com/the-future-of...
# 147   148.0  https://insights.blackcoffer.com/big-data-anal...
# 148   149.0  https://insights.blackcoffer.com/business-anal...
# 149   150.0  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                30               5       -0.076923            0.107692
# ...

# %%
output.to_excel("./Final Result/Output Data Structure.xlsx")
