# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_email = pd.read_csv('/content/drive/MyDrive/spam_ham_dataset.csv')

# %%
df_email.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
###Drop Nan Values
df_email=df_email.dropna()
df_email.reset_index(inplace=True)

# %%
import re
import string
def cleaning(txt):
    # case folding
    text = txt.lower()
    # remove multiple space, tabs, dan newlines
    text = re.sub('\s+',' ',text)
    # remove links
    text = text.replace("http://", " ").replace("https://", " ")
    # remove special characters
    text = text.encode('ascii', 'replace').decode('ascii')
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove punctuation
    text = ''.join([word for word in text if word not in string.punctuation])
    #remove single character
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    #remove numbers
    text = re.sub(r"\d+", "", text)
    #remove multiple spaces (again)
    text = re.sub('\s+',' ',text)
    return text

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem(email):
    email = email.split()
    email = [ps.stem(word) for word in email if not word in stopwords.words('english')]
    return email

# %%
#Data Preprocessing
df_email['text'] = df_email['text'].apply(lambda x: cleaning(x))

# %%
df_email['text'] = df_email['text'].apply(lambda x: stem(x))

# %%
df_email.head()
# Out:
#    index  Unnamed: 0 label                                               text  \
# 0      0         605   ham  [subject, enron, methanol, meter, follow, note...
# 1      1        2349   ham  [subject, hpl, nom, januari, see, attach, file...
# 2      2        3624   ham  [subject, neon, retreat, ho, ho, ho, around, w...
# 3      3        4685  spam  [subject, photoshop, window, offic, cheap, mai...
# 4      4        2030   ham  [subject, indian, spring, deal, book, teco, pv...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
## Get the Independent Features
X=df_email.drop(['index','label_num','label','Unnamed: 0'],axis=1)

# %%
## Get the Dependent features
y=df_email['label_num']

# %%
X.shape
# Out:
# (5171, 1)

# %%
X
# Out:
#                                                    text
# 0     [subject, enron, methanol, meter, follow, note...
# 1     [subject, hpl, nom, januari, see, attach, file...
# 2     [subject, neon, retreat, ho, ho, ho, around, w...
# 3     [subject, photoshop, window, offic, cheap, mai...
# 4     [subject, indian, spring, deal, book, teco, pv...
# ...                                                 ...
# 5166  [subject, put, ft, transport, volum, decreas, ...
# 5167  [subject, follow, nom, hpl, take, extra, mmcf,...
# 5168  [subject, calpin, daili, ga, nomin, juli, ment...
# 5169  [subject, industri, worksheet, august, activ, ...
# 5170  [subject, import, onlin, bank, alert, dear, va...
#
# [5171 rows x 1 columns]

# %%
y.shape
# Out:
# (5171,)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5166    0
# 5167    0
# 5168    0
# 5169    0
# 5170    1
# Name: label_num, Length: 5171, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.text, y, test_size=0.33, random_state=42)

# %%
import gensim

# %%
# Train the word2vec model
#feature size = 100
w2v_model = gensim.models.Word2Vec(X_train,size=100,window=5,min_count=2)

# %%
w2v_model.wv.index2word
# Out:
# ['ect',
#  'subject',
#  'hou',
#  'enron',
#  'deal',
#  'pleas',
#  'com',
#  'ga',
#  'meter',
#  'hpl',
#  'cc',
#  'thank',
#  'pm',
#  'need',
#  'daren',
#  'price',
#  'forward',
#  'corp',
#  'volum',
#  'day',
#  'know',
#  'get',
#  'compani',
#  'chang',
#  'product',
#  'new',
#  'may',
#  'inform',
#  'mmbtu',
#  'see',
#  'nom',
#  'time',
#  'http',
#  'let',
#  'attach',
#  'contract',
#  'farmer',
#  'call',
#  'would',
#  'month',
#  'nomin',
#  'us',
#  'one',
#  'mail',
#  'xl',
#  'messag',
#  'sale',
#  'use',
#  'question',
#  'flow',
#  'follow',
#  'email',
#  'th',
#  'juli',
#  'sitara',
#  'texa',
#  'manag',
#  'look',
#  'robert',
#  'work',
#  'www',
#  'ticket',
#  'want',
#  'servic',
#  'report',
#  'list',
#  'energi',
#  'number',
#  'go',
#  'file',
#  'also',
#  'sent',
#  'actual',
#  'contact',
#  'bob',
#  'make',
#  'ena',
#  'order',
#  'like',
#  'receiv',
#  'schedul',
#  'market',
#  'effect',
#  'system',
#  'purchas',
#  'origin',
#  'busi',
#  'secur',
#  'take',
#  'avail',
#  'back',
#  'daili',
#  'statement',
#  'help',
#  'provid',
#  'font',
#  'per',
#  'could',
#  'march',
#  'account',
#  'includ',
#  'pec',
#  'request',
#  'free',
#  'current',
#  'stock',
#  'year',
#  'rate',
#  'offic',
#  'mari',
#  'offer',
#  'inc',
#  'april',
#  'deliveri',
#  'invest',
#  'first',
#  'week',
#  'line',
#  'transport',
#  'well',
#  'oper',
#  'nbsp',
#  'gari',
#  'today',
#  'base',
#  'custom',
#  'plant',
#  'alloc',
#  'trade',
#  'name',
#  'issu',
#  'process',
#  'addit',
#  'set',
#  'show',
#  'creat',
#  'date',
#  'activ',
#  'click',
#  'vanc',
#  'send',
#  'revis',
#  'last',
#  'within',
#  'pill',
#  'meet',
#  'expect',
#  'melissa',
#  'ami',
#  'agreement',
#  'fuel',
#  'next',
#  'group',
#  'net',
#  'fw',
#  'think',
#  'note',
#  'point',
#  'term',
#  'size',
#  'two',
#  'address',
#  'june',
#  'pipelin',
#  'jacki',
#  'save',
#  'houston',
#  'teco',
#  'georg',
#  'desk',
#  'januari',
#  'oil',
#  'america',
#  'tenaska',
#  'north',
#  'link',
#  'best',
#  'smith',
#  'path',
#  'special',
#  'tri',
#  'total',
#  'confirm',
#  'come',
#  'phone',
#  'enter',
#  'place',
#  'start',
#  'find',
#  'review',
#  'regard',
#  'give',
#  'pat',
#  'fax',
#  'due',
#  'made',
#  'less',
#  'hour',
#  'project',
#  'transact',
#  'requir',
#  'money',
#  'state',
#  'mark',
#  'david',
#  'mani',
#  'peopl',
#  'estim',
#  'updat',
#  'check',
#  'continu',
#  'futur',
#  'hsc',
#  'tap',
#  'complet',
#  'octob',
#  'plan',
#  'high',
#  'pay',
#  'remov',
#  'friday',
#  'util',
#  'gener',
#  'problem',
#  'end',
#  'onlin',
#  'lisa',
#  'co',
#  'team',
#  'td',
#  'august',
#  'invoic',
#  'person',
#  'cotten',
#  'susan',
#  'intern',
#  'taylor',
#  'buy',
#  'counterparti',
#  'septemb',
#  'move',
#  'perform',
#  'interest',
#  'said',
#  'increas',
#  'feb',
#  'suppli',
#  'risk',
#  'resourc',
#  'window',
#  'michael',
#  'still',
#  'steve',
#  'unit',
#  'differ',
#  'chokshi',
#  'fyi',
#  'result',
#  'cost',
#  'access',
#  'aime',
#  'believ',
#  'way',
#  'copi',
#  'good',
#  'internet',
#  'even',
#  'right',
#  'tu',
#  'john',
#  'sure',
#  'site',
#  'keep',
#  'fee',
#  'pt',
#  'correct',
#  'discuss',
#  'natur',
#  'ship',
#  'home',
#  'iv',
#  'tom',
#  'million',
#  'share',
#  'unifi',
#  'sell',
#  'control',
#  'decemb',
#  'spot',
#  'softwar',
#  '\x01',
#  'begin',
#  'respons',
#  'sinc',
#  'news',
#  'develop',
#  'advis',
#  'employe',
#  'info',
#  'without',
#  'novemb',
#  'data',
#  'eastran',
#  'posit',
#  'height',
#  'detail',
#  'program',
#  'st',
#  'monday',
#  'global',
#  'februari',
#  'great',
#  'support',
#  'young',
#  'extend',
#  'duke',
#  'past',
#  'wellhead',
#  'much',
#  'part',
#  'option',
#  'hplc',
#  'clyne',
#  'parti',
#  'ask',
#  'visit',
#  'industri',
#  'put',
#  'locat',
#  'computron',
#  'corpor',
#  'possibl',
#  'megan',
#  'book',
#  'mobil',
#  'demand',
#  'grave',
#  'na',
#  'web',
#  'section',
#  'repli',
#  'everi',
#  'produc',
#  'lee',
#  'approv',
#  'must',
#  'br',
#  'jan',
#  'brian',
#  'bill',
#  'power',
#  'agre',
#  'world',
#  'pg',
#  'assist',
#  'limit',
#  'type',
#  'stop',
#  'technolog',
#  'abl',
#  'gather',
#  'feel',
#  'via',
#  'microsoft',
#  'form',
#  'releas',
#  'thing',
#  'read',
#  'tuesday',
#  'rita',
#  'id',
#  'applic',
#  'long',
#  'final',
#  'talk',
#  'act',
#  'hplno',
#  'someon',
#  'period',
#  'howev',
#  'thru',
#  'pipe',
#  'meyer',
#  'profession',
#  'ce',
#  'handl',
#  'imag',
#  'done',
#  'deliv',
#  'charg',
#  'color',
#  'thursday',
#  'famili',
#  'close',
#  'tx',
#  'notic',
#  'say',
#  'financi',
#  'fact',
#  'howard',
#  'katherin',
#  'dollar',
#  'allen',
#  'center',
#  'ad',
#  'lloyd',
#  'face',
#  'hope',
#  'spreadsheet',
#  'indic',
#  'field',
#  'buyback',
#  'featur',
#  'partner',
#  'soon',
#  'dec',
#  'logist',
#  'jame',
#  'prior',
#  'width',
#  'user',
#  'advic',
#  'regist',
#  'track',
#  'txu',
#  'letter',
#  'doc',
#  'wynn',
#  'hank',
#  'lannou',
#  'ls',
#  'jone',
#  'run',
#  'add',
#  'caus',
#  'carlo',
#  'medic',
#  'zero',
#  'adob',
#  'materi',
#  'old',
#  'sourc',
#  'enronxg',
#  'error',
#  'imbal',
#  'allow',
#  'aol',
#  'top',
#  'import',
#  'concern',
#  'iferc',
#  'direct',
#  'understand',
#  'event',
#  'thu',
#  'reflect',
#  'anyth',
#  'record',
#  'document',
#  'prescript',
#  'mike',
#  'viagra',
#  'mean',
#  'select',
#  'paid',
#  'assign',
#  'repres',
#  'anoth',
#  'suit',
#  'cd',
#  'facil',
#  'download',
#  'firm',
#  'cut',
#  'public',
#  'three',
#  'cover',
#  'pop',
#  'xp',
#  'aep',
#  'weissman',
#  'swing',
#  'valid',
#  'server',
#  'hi',
#  'canada',
#  'content',
#  'got',
#  'de',
#  'full',
#  'present',
#  'sever',
#  'explor',
#  'commun',
#  'clear',
#  'clem',
#  'refer',
#  'either',
#  'page',
#  'contain',
#  'midcon',
#  'scott',
#  'view',
#  'payment',
#  'reason',
#  'equistar',
#  'respect',
#  'zone',
#  'brenda',
#  'sherlyn',
#  'low',
#  'impact',
#  'hplo',
#  'href',
#  'newslett',
#  'return',
#  'camp',
#  'east',
#  'anita',
#  'item',
#  'love',
#  'relat',
#  'qualiti',
#  'entex',
#  'morn',
#  'ciali',
#  'distribut',
#  'websit',
#  'remain',
#  'storag',
#  'solut',
#  'tess',
#  'intend',
#  'involv',
#  'alreadi',
#  'redeliveri',
#  'weekend',
#  'word',
#  'expens',
#  'richard',
#  'case',
#  'valu',
#  'exchang',
#  'hold',
#  'comput',
#  'cornhusk',
#  'loss',
#  'area',
#  'wednesday',
#  'real',
#  'outag',
#  'might',
#  'expir',
#  'suggest',
#  'tax',
#  'except',
#  'kati',
#  'pass',
#  'ms',
#  'claim',
#  'citi',
#  'im',
#  'action',
#  'everyon',
#  'align',
#  'stephani',
#  'william',
#  'miss',
#  'amount',
#  'survey',
#  'adjust',
#  'lauri',
#  'success',
#  'calpin',
#  'better',
#  'watch',
#  'announc',
#  'victor',
#  'style',
#  'someth',
#  'ray',
#  'associ',
#  'version',
#  'tr',
#  'game',
#  'effort',
#  'reserv',
#  'yet',
#  'immedi',
#  'consid',
#  'wish',
#  'valley',
#  'design',
#  'tomorrow',
#  'second',
#  'thought',
#  'open',
#  'unsubscrib',
#  'pef',
#  'anyon',
#  'cash',
#  'html',
#  'acton',
#  'around',
#  'darren',
#  'donald',
#  'vlt',
#  'target',
#  'coastal',
#  'stacey',
#  'termin',
#  'big',
#  'credit',
#  'left',
#  'ee',
#  'accept',
#  'gc',
#  'rodriguez',
#  'never',
#  'dave',
#  'retail',
#  'med',
#  'investor',
#  'cec',
#  'promot',
#  'train',
#  'littl',
#  'cynthia',
#  'publish',
#  'drug',
#  'head',
#  'lst',
#  'cotton',
#  'level',
#  'easi',
#  'sign',
#  'owner',
#  'countri',
#  'network',
#  'director',
#  'union',
#  'properti',
#  'necessari',
#  'donna',
#  'identifi',
#  'stone',
#  'shut',
#  'soft',
#  'charli',
#  'thoma',
#  'write',
#  'paliourg',
#  'appear',
#  'cheryl',
#  'life',
#  'central',
#  'alway',
#  'happen',
#  'drive',
#  'third',
#  'code',
#  'beaumont',
#  'mg',
#  'legal',
#  'answer',
#  'late',
#  'jeff',
#  'titl',
#  'basi',
#  'fill',
#  'gco',
#  'els',
#  'bring',
#  'trader',
#  'friend',
#  'later',
#  'member',
#  'star',
#  'turn',
#  'settlement',
#  'potenti',
#  'opportun',
#  'transfer',
#  'rememb',
#  'herod',
#  'wait',
#  'edit',
#  'togeth',
#  'index',
#  'night',
#  'therefor',
#  'commerci',
#  'la',
#  'sept',
#  'ic',
#  'found',
#  'lead',
#  'everyth',
#  'ranch',
#  'health',
#  'profil',
#  'reinhardt',
#  'hess',
#  'baumbach',
#  'schumack',
#  'approxim',
#  'card',
#  'hplnl',
#  'privat',
#  'presid',
#  'live',
#  'print',
#  'roll',
#  'execut',
#  'play',
#  'lsk',
#  'jennif',
#  'arrang',
#  'carthag',
#  'recent',
#  'guarante',
#  'connect',
#  'prepar',
#  'small',
#  'koch',
#  'voip',
#  'decid',
#  'appreci',
#  'guy',
#  'mention',
#  'growth',
#  'sat',
#  'ken',
#  'stack',
#  'methanol',
#  'reduc',
#  'join',
#  'china',
#  'verifi',
#  'luong',
#  'jim',
#  'brand',
#  'specif',
#  'south',
#  'purpos',
#  'al',
#  'improv',
#  'anticip',
#  'fix',
#  'etc',
#  'staff',
#  'learn',
#  'leav',
#  'edward',
#  'password',
#  'liz',
#  'portfolio',
#  'box',
#  'thousand',
#  'major',
#  'becom',
#  'express',
#  'side',
#  'feedback',
#  'voic',
#  'asset',
#  'parker',
#  'hard',
#  'mid',
#  'cannot',
#  'affili',
#  'poorman',
#  'papayoti',
#  'bryan',
#  'ever',
#  'balanc',
#  'submit',
#  'determin',
#  'particip',
#  'packag',
#  'shop',
#  'lot',
#  'statu',
#  'bank',
#  'london',
#  'probabl',
#  'dow',
#  'longer',
#  'afternoon',
#  'text',
#  'latest',
#  'normal',
#  'tell',
#  'pro',
#  'duti',
#  'reach',
#  'kind',
#  'mr',
#  'sorri',
#  'monthli',
#  'short',
#  'receipt',
#  'depart',
#  'pain',
#  'oo',
#  'hear',
#  'dy',
#  'valign',
#  'told',
#  'white',
#  'doctor',
#  'build',
#  'dealer',
#  'ltd',
#  'condit',
#  'plu',
#  'src',
#  'border',
#  'physic',
#  'cernosek',
#  'travel',
#  'rd',
#  'forc',
#  'larg',
#  'resolv',
#  'enw',
#  'channel',
#  'oasi',
#  'devon',
#  'moopid',
#  'hotlist',
#  'browser',
#  'experi',
#  'el',
#  'waha',
#  'key',
#  'sandi',
#  'choos',
#  'bodi',
#  'comment',
#  'load',
#  'bridg',
#  'directli',
#  'idea',
#  'occur',
#  'care',
#  'step',
#  'bellami',
#  'class',
#  'janet',
#  'lp',
#  'fund',
#  'karen',
#  'exist',
#  'valero',
#  'ensur',
#  'lone',
#  'vacat',
#  'tab',
#  'strong',
#  'propos',
#  'factor',
#  'subscrib',
#  'format',
#  'minut',
#  'room',
#  'lsp',
#  'enserch',
#  'readi',
#  'usa',
#  'land',
#  'men',
#  'protect',
#  'awar',
#  'taken',
#  'lose',
#  'notifi',
#  'financ',
#  'initi',
#  'mm',
#  'hey',
#  'ali',
#  'mailto',
#  'lamadrid',
#  'sun',
#  'video',
#  'dfarmer',
#  'hr',
#  'cleburn',
#  'php',
#  'given',
#  'press',
#  'instruct',
#  'feder',
#  'seek',
#  'revenu',
#  'sold',
#  'man',
#  'abil',
#  'age',
#  'draft',
#  'function',
#  'individu',
#  'photoshop',
#  'test',
#  'dan',
#  'quot',
#  'mx',
#  'analyst',
#  'california',
#  'matter',
#  'hill',
#  'realli',
#  'green',
#  'chanc',
#  'dear',
#  'safe',
#  'capit',
#  'enerfin',
#  'lamphier',
#  'neal',
#  'away',
#  'shell',
#  'nd',
#  'pool',
#  'complianc',
#  'mccoy',
#  'saturday',
#  'coupl',
#  'stori',
#  'knle',
#  'stay',
#  'upon',
#  'quick',
#  'mind',
#  'tetco',
#  'american',
#  'measur',
#  'averag',
#  'weight',
#  'music',
#  'hall',
#  'dynegi',
#  'gain',
#  'teja',
#  'beverli',
#  'discount',
#  'super',
#  'herrera',
#  'hesco',
#  'stranger',
#  'earli',
#  'sunday',
#  'appli',
#  'king',
#  'pc',
#  'spam',
#  'quit',
#  'wide',
#  'park',
#  'certif',
#  'pharmaci',
#  'object',
#  'certain',
#  'neon',
#  'gift',
#  'light',
#  'enrononlin',
#  'noth',
#  'model',
#  'apach',
#  'avila',
#  'mcf',
#  'nov',
#  'superti',
#  'electr',
#  'middl',
#  'biz',
#  'research',
#  'referenc',
#  'other',
#  'god',
#  'girl',
#  'opinion',
#  'nation',
#  'eb',
#  'tina',
#  'confidenti',
#  'pictur',
#  'profit',
#  'mine',
#  'enjoy',
#  'media',
#  'spoke',
#  'riley',
#  'store',
#  'mar',
#  'though',
#  'exxon',
#  'whole',
#  ...]

# %%
# Find the most similar words to from our trained model
w2v_model.wv.most_similar('prize')
# Out:
# [('throughout', 0.9951569437980652),
#  ('consider', 0.9938293099403381),
#  ('advantag', 0.9937296509742737),
#  ('earn', 0.9934826493263245),
#  ('warehous', 0.9928135275840759),
#  ('shift', 0.9920439720153809),
#  ('safeti', 0.9909731149673462),
#  ('foreign', 0.9908500909805298),
#  ('realiz', 0.9908014535903931),
#  ('biggest', 0.990614116191864)]

# %%
import numpy as np

# %%
w2v_model.wv['avoid']
# Out:
# array([ 0.10501271,  0.12230531, -0.10374425, -0.12222383,  0.3759728 ,
#        -0.09446032, -0.7094072 , -0.32537597,  0.3653539 , -0.65279573,
#        -0.31621996,  0.19112352, -1.0885036 ,  0.03290749,  0.39555222,
#        -0.10785022, -0.30581284, -0.3086248 ,  0.39919022,  0.24294563,
#         0.45278248,  0.35500586,  0.19979985, -0.17681244, -0.20586455,
#         0.28814113,  0.06813863,  0.35542285,  0.21221395,  0.12143993,
#        -0.48798013,  0.03277368, -0.50559115, -0.07769861, -0.22726811,
#         0.10593437, -0.42214286, -0.12749334, -0.45165217,  0.19127622,
#         0.3830705 , -0.513182  , -0.30308124,  0.12387617,  0.15186532,
#         0.10401089,  0.66376346,  0.00437571, -0.3261038 , -0.10864793,
#         0.31203914,  0.4693572 , -0.48602095, -0.15974747,  0.11026616,
#         0.43967316, -0.23003256,  0.18453014,  0.06043662,  0.26322594,
#         0.41022217, -0.11842853, -0.1433158 , -0.14381866,  0.18687566,
#        -0.01407259,  0.28379083, -0.52541095, -0.19491336,  0.45343924,
#         0.6202921 ,  0.0440082 , -0.03077975,  0.29118884,  0.273471  ,
#        -0.01496165,  0.13723916, -0.043864  , -0.03795921, -0.10268828,
#        -0.02947639,  0.40799743,  0.31515604, -0.15377781, -0.19299014,
#         0.466778  ,  0.42915183,  0.18162513,  0.17384288, -0.02100175,
#         0.45578703,  0.12195504,  0.06678769,  0.40377662, -0.2272925 ,
#        -0.27800333, -0.14172252, -0.62272006,  0.3168153 , -0.08701424],
#       dtype=float32)

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
# Replace the words in each text message with the learned word vector
words = set(w2v_model.wv.index2word)
X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_train])
X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_test])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   import sys

# %%
X_train_vect[0]
# Out:
# array([[-0.32109797,  1.2493627 ,  0.13421297, ..., -0.54885006,
#         -0.09748083, -0.17088957],
#        [ 0.00716424,  0.05376712,  0.01793709, ..., -0.08651087,
#          0.03384385, -0.01534526],
#        [ 1.385162  , -0.06763467,  0.4508465 , ...,  0.17989781,
#         -0.08594676,  0.00666128],
#        ...,
#        [ 0.9868093 , -0.1663161 ,  1.4514278 , ..., -0.32475522,
#          0.03202817, -1.1119998 ],
#        [ 0.14848748,  0.22947003,  1.3504449 , ..., -0.42533162,
#         -0.10086901, -0.9717226 ],
#        [-0.8943951 ,  1.0501251 ,  0.8053407 , ..., -0.981951  ,
#          0.31124598, -0.51178205]], dtype=float32)

# %%
X_train_vect[0].shape
# Out:
# (35, 100)

# %%
X_test_vect[0].shape
# Out:
# (11, 100)

# %%
# Average the word vectors for each sentence (and assign a vector of zeros if the model
# did not learn any of the words in the text message during training
X_train_vect_avg = []
for v in X_train_vect:
    if v.size:
        X_train_vect_avg.append(v.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(100, dtype=float))
        
X_test_vect_avg = []
for v in X_test_vect:
    if v.size:
        X_test_vect_avg.append(v.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(100, dtype=float))

# %%
X_train_vect_avg[0].shape
# Out:
# (100,)

# %% [markdown]
# Fit RandomForestClassifier On Top Of Word Vector

# %%
# Instantiate and fit a basic Random Forest model on top of the vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect_avg)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.917 / Recall: 0.907 / Accuracy: 0.953
